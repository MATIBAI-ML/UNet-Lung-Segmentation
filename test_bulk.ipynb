# %%
import numpy as np
import tensorflow as tf
import cv2
import os
# Out:
# /Users/tyronemariano/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#save best model
best_model_file = os.path.expanduser("~/Desktop/lung-Unet.keras")
model = tf.keras.models.load_model(best_model_file)
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ activation_9[0][… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ activation_13[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ activation_15[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ conv2d_18[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 94,183,941 (359.28 MB)
#  Trainable params: 31,390,721 (119.75 MB)
#  Non-trainable params: 11,776 (46.00 KB)
#  Optimizer params: 62,781,444 (239.49 MB)
# None

# %%
input_folder = "data"  # Change to your actual input folder
output_folder = "segmented"
os.makedirs(output_folder, exist_ok=True)

# %%
width = 256
height = 256

# %%
for filename in os.listdir(input_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg')):  # Ensure processing only image files
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)
        
        if img is None:
            print(f"Skipping {filename}, unable to read image.")
            continue
        
        img_resized = cv2.resize(img, (width, height)) / 255.0
        img_for_model = np.expand_dims(img_resized, axis=0)
        
        # Predict mask
        p = model.predict(img_for_model)
        result_mask = p[0]
        
        # Binarize mask
        result_mask[result_mask <= 0.5] = 0
        result_mask[result_mask > 0.5] = 255
        
        # Resize mask back to original dimensions
        mask_resized = cv2.resize(result_mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_AREA)
        mask_resized = mask_resized.astype(np.uint8)
        
        # Convert to 3-channel image
        mask_bgr = cv2.cvtColor(mask_resized, cv2.COLOR_GRAY2BGR)
        
        # Apply mask
        segmented_image = cv2.bitwise_and(img, mask_bgr)
        
        # Save the segmented image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")

print("Segmentation complete.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# Processed and saved: segmented/MCUCXR_0023_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Processed and saved: segmented/MCUCXR_0383_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Processed and saved: segmented/MCUCXR_0103_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Processed and saved: segmented/MCUCXR_0162_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Processed and saved: segmented/MCUCXR_0082_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Processed and saved: segmented/MCUCXR_0042_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Processed and saved: segmented/MCUCXR_0367_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Processed and saved: segmented/MCUCXR_0005_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed and saved: segmented/MCUCXR_0040_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Processed and saved: segmented/MCUCXR_0038_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed and saved: segmented/MCUCXR_0080_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# Processed and saved: segmented/MCUCXR_0144_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 868ms/step
# Processed and saved: segmented/MCUCXR_0101_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# Processed and saved: segmented/MCUCXR_0059_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# Processed and saved: segmented/MCUCXR_0021_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed and saved: segmented/MCUCXR_0064_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed and saved: segmented/MCUCXR_0099_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Processed and saved: segmented/MCUCXR_0258_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Processed and saved: segmented/MCUCXR_0060_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed and saved: segmented/MCUCXR_0001_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Processed and saved: segmented/MCUCXR_0044_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Processed and saved: segmented/MCUCXR_0084_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed and saved: segmented/MCUCXR_0140_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# Processed and saved: segmented/MCUCXR_0079_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Processed and saved: segmented/MCUCXR_0243_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Processed and saved: segmented/MCUCXR_0142_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Processed and saved: segmented/MCUCXR_0086_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Processed and saved: segmented/MCUCXR_0003_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Processed and saved: segmented/MCUCXR_0046_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed and saved: segmented/MCUCXR_0182_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# Processed and saved: segmented/MCUCXR_0027_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Processed and saved: segmented/MCUCXR_0062_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Processed and saved: segmented/MCUCXR_0166_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Processed and saved: segmented/MCUCXR_0387_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Processed and saved: segmented/MCUCXR_0081_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Processed and saved: segmented/MCUCXR_0399_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Processed and saved: segmented/MCUCXR_0041_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Processed and saved: segmented/MCUCXR_0004_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Processed and saved: segmented/MCUCXR_0218_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed and saved: segmented/MCUCXR_0020_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Processed and saved: segmented/MCUCXR_0058_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Processed and saved: segmented/MCUCXR_0338_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Processed and saved: segmented/MCUCXR_0100_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Processed and saved: segmented/MCUCXR_0126_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Processed and saved: segmented/MCUCXR_0102_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed and saved: segmented/MCUCXR_0022_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Processed and saved: segmented/MCUCXR_0043_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Processed and saved: segmented/MCUCXR_0006_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Processed and saved: segmented/MCUCXR_0083_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Processed and saved: segmented/MCUCXR_0203_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# Processed and saved: segmented/MCUCXR_0282_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Processed and saved: segmented/MCUCXR_0047_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# Processed and saved: segmented/MCUCXR_0002_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Processed and saved: segmented/MCUCXR_0362_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Processed and saved: segmented/MCUCXR_0087_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed and saved: segmented/MCUCXR_0223_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Processed and saved: segmented/MCUCXR_0266_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# Processed and saved: segmented/MCUCXR_0063_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Processed and saved: segmented/MCUCXR_0026_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Processed and saved: segmented/MCUCXR_0061_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed and saved: segmented/MCUCXR_0024_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Processed and saved: segmented/MCUCXR_0301_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed and saved: segmented/MCUCXR_0019_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Processed and saved: segmented/MCUCXR_0264_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Processed and saved: segmented/MCUCXR_0085_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Processed and saved: segmented/MCUCXR_0104_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Processed and saved: segmented/MCUCXR_0141_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed and saved: segmented/MCUCXR_0045_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Processed and saved: segmented/MCUCXR_0049_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Processed and saved: segmented/MCUCXR_0170_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Processed and saved: segmented/MCUCXR_0108_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Processed and saved: segmented/MCUCXR_0089_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Processed and saved: segmented/MCUCXR_0031_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed and saved: segmented/MCUCXR_0074_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# Processed and saved: segmented/MCUCXR_0375_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Processed and saved: segmented/MCUCXR_0194_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed and saved: segmented/MCUCXR_0015_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Processed and saved: segmented/MCUCXR_0090_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Processed and saved: segmented/MCUCXR_0255_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Processed and saved: segmented/MCUCXR_0028_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Processed and saved: segmented/MCUCXR_0348_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Processed and saved: segmented/MCUCXR_0113_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Processed and saved: segmented/MCUCXR_0092_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed and saved: segmented/MCUCXR_0017_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed and saved: segmented/MCUCXR_0052_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Processed and saved: segmented/MCUCXR_0196_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Processed and saved: segmented/MCUCXR_0316_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Processed and saved: segmented/MCUCXR_0393_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Processed and saved: segmented/MCUCXR_0072_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Processed and saved: segmented/MCUCXR_0117_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed and saved: segmented/MCUCXR_0096_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Processed and saved: segmented/MCUCXR_0253_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Processed and saved: segmented/MCUCXR_0013_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Processed and saved: segmented/MCUCXR_0056_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Processed and saved: segmented/MCUCXR_0011_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Processed and saved: segmented/MCUCXR_0054_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Processed and saved: segmented/MCUCXR_0334_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Processed and saved: segmented/MCUCXR_0309_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Processed and saved: segmented/MCUCXR_0069_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed and saved: segmented/MCUCXR_0251_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Processed and saved: segmented/MCUCXR_0094_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Processed and saved: segmented/MCUCXR_0150_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Processed and saved: segmented/MCUCXR_0275_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Processed and saved: segmented/MCUCXR_0008_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Processed and saved: segmented/MCUCXR_0035_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Processed and saved: segmented/MCUCXR_0070_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Processed and saved: segmented/MCUCXR_0053_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Processed and saved: segmented/MCUCXR_0016_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Processed and saved: segmented/MCUCXR_0213_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Processed and saved: segmented/MCUCXR_0173_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Processed and saved: segmented/MCUCXR_0077_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Processed and saved: segmented/MCUCXR_0352_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Processed and saved: segmented/MCUCXR_0075_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Processed and saved: segmented/MCUCXR_0030_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Processed and saved: segmented/MCUCXR_0350_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Processed and saved: segmented/MCUCXR_0390_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Processed and saved: segmented/MCUCXR_0048_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Processed and saved: segmented/MCUCXR_0091_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Processed and saved: segmented/MCUCXR_0029_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Processed and saved: segmented/MCUCXR_0254_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# Processed and saved: segmented/MCUCXR_0195_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Processed and saved: segmented/MCUCXR_0051_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Processed and saved: segmented/MCUCXR_0294_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Processed and saved: segmented/MCUCXR_0331_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Processed and saved: segmented/MCUCXR_0068_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Processed and saved: segmented/MCUCXR_0095_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Processed and saved: segmented/MCUCXR_0055_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Processed and saved: segmented/MCUCXR_0228_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Processed and saved: segmented/MCUCXR_0354_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Processed and saved: segmented/MCUCXR_0311_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Processed and saved: segmented/MCUCXR_0071_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Processed and saved: segmented/MCUCXR_0289_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Processed and saved: segmented/MCUCXR_0188_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Processed and saved: segmented/MCUCXR_0369_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Processed and saved: segmented/MCUCXR_0313_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Processed and saved: segmented/MCUCXR_0372_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Processed and saved: segmented/MCUCXR_0057_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Processed and saved: segmented/MCUCXR_0097_0.png
# Segmentation complete.
